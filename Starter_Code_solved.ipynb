# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN', 'NAME'])

# Display the first few rows of the updated dataframe
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()

# Display the number of unique values in each column
print(unique_values)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts
application_type_counts = application_df['APPLICATION_TYPE'].value_counts()
print(application_type_counts)

# Determine which APPLICATION_TYPE values to replace
# Replace in dataframe
application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].apply(lambda x: 'Other' if application_type_counts[x] < 100 else x)

# Check to make sure binning was successful
print(application_df['APPLICATION_TYPE'].value_counts())
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: count, dtype: int64

# %%
# Choose a cutoff value
cutoff_value = 100

# Create a list of application types to be replaced
application_types_to_replace = application_type_counts[application_type_counts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, "Other")

# Check to make sure replacement was successful
print(application_df['APPLICATION_TYPE'].value_counts())
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts
classification_counts = application_df['CLASSIFICATION'].value_counts()
print(classification_counts)

# Determine which CLASSIFICATION values to replace
# Replace in dataframe
classification_cutoff_value = 100
classification_to_replace = classification_counts[classification_counts < classification_cutoff_value].index.tolist()

# Replace in dataframe
for cls in classification_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure replacement was successful
print(application_df['CLASSIFICATION'].value_counts())
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts greater than 1
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts_gt1 = classification_counts[classification_counts > 1]
print(classification_counts_gt1)

# Determine which CLASSIFICATION values to replace
classification_cutoff_value = 100
classification_to_replace = classification_counts[classification_counts < classification_cutoff_value].index.tolist()

# Replace in dataframe
for cls in classification_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure replacement was successful
print(application_df['CLASSIFICATION'].value_counts())
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value
cutoff_value = 100

# Create a list of classifications to be replaced
classifications_to_replace = classification_counts[classification_counts < cutoff_value].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure replacement was successful
print(application_df['CLASSIFICATION'].value_counts())
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64

# %%
# Convert categorical variables to numeric using pd.get_dummies
X_train_encoded = pd.get_dummies(X_train)
X_test_encoded = pd.get_dummies(X_test)

# Align the test set to the training set
X_train_encoded, X_test_encoded = X_train_encoded.align(X_test_encoded, join='left', axis=1, fill_value=0)

# Ensure all columns are now numeric
print(X_train_encoded.dtypes)

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train_encoded)

# Scale the data
X_train_scaled = X_scaler.transform(X_train_encoded)
X_test_scaled = X_scaler.transform(X_test_encoded)

# Display the shapes of the scaled training and testing datasets
print(f"X_train_scaled shape: {X_train_scaled.shape}")
print(f"X_test_scaled shape: {X_test_scaled.shape}")
# Out:
# STATUS                          int64
# ASK_AMT                         int64
# APPLICATION_TYPE_Other           bool
# APPLICATION_TYPE_T10             bool
# APPLICATION_TYPE_T19             bool
# APPLICATION_TYPE_T3              bool
# APPLICATION_TYPE_T4              bool
# APPLICATION_TYPE_T5              bool
# APPLICATION_TYPE_T6              bool
# APPLICATION_TYPE_T7              bool
# APPLICATION_TYPE_T8              bool
# APPLICATION_TYPE_T9              bool
# AFFILIATION_CompanySponsored     bool
# AFFILIATION_Family/Parent        bool
# AFFILIATION_Independent          bool
# AFFILIATION_National             bool
# AFFILIATION_Other                bool
# AFFILIATION_Regional             bool
# CLASSIFICATION_C1000             bool
# CLASSIFICATION_C1200             bool
# CLASSIFICATION_C1270             bool
# CLASSIFICATION_C1700             bool
# CLASSIFICATION_C2000             bool
# CLASSIFICATION_C2100             bool
# CLASSIFICATION_C2700             bool
# CLASSIFICATION_C3000             bool
# CLASSIFICATION_C4000             bool
# CLASSIFICATION_C5000             bool
# CLASSIFICATION_C7000             bool
# CLASSIFICATION_Other             bool
# USE_CASE_CommunityServ           bool
# USE_CASE_Heathcare               bool
# USE_CASE_Other                   bool
# USE_CASE_Preservation            bool
# USE_CASE_ProductDev              bool
# ORGANIZATION_Association         bool
# ORGANIZATION_Co-operative        bool
# ORGANIZATION_Corporation         bool
# ORGANIZATION_Trust               bool
# INCOME_AMT_0                     bool
# INCOME_AMT_1-9999                bool
# INCOME_AMT_10000-24999           bool
# INCOME_AMT_100000-499999         bool
# INCOME_AMT_10M-50M               bool
# INCOME_AMT_1M-5M                 bool
# INCOME_AMT_25000-99999           bool
# INCOME_AMT_50M+                  bool
# INCOME_AMT_5M-10M                bool
# SPECIAL_CONSIDERATIONS_N         bool
# SPECIAL_CONSIDERATIONS_Y         bool
# dtype: object
# X_train_scaled shape: (27439, 50)
# X_test_scaled shape: (6860, 50)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_c/0pvwl5014v1b7mmhb37zxl1c0000gn/T/ipykernel_66158/3690512841.py in ?()
#       1 # Create a StandardScaler instances
#       2 scaler = StandardScaler()
#       3
#       4 # Fit the StandardScaler
# ----> 5 X_scaler = scaler.fit(X_train)
#       6
#       7 # Scale the data
#       8 X_train_scaled = X_scaler.transform(X_train)
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     874             Fitted scaler.
#     875         """
#     876         # Reset internal state before fitting
#     877         self._reset()
# --> 878         return self.partial_fit(X, y, sample_weight)
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     910         self : object
#     911             Fitted scaler.
#     912         """
#     913         first_call = not hasattr(self, "n_samples_seen_")
# --> 914         X = self._validate_data(
#     915             X,
#     916             accept_sparse=("csr", "csc"),
#     917             dtype=FLOAT_DTYPES,
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1009                         )
#    1010                     array = xp.astype(array, dtype, copy=False)
#    1011                 else:
#    1012                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1013             except ComplexWarning as complex_warning:
#    1014                 raise ValueError(
#    1015                     "Complex data not supported\n{}\n".format(array)
#    1016                 ) from complex_warning
#
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     747         # Use NumPy API to support order
#     748         if copy is True:
#     749             array = numpy.array(array, order=order, dtype=dtype)
#     750         else:
# --> 751             array = numpy.asarray(array, order=order, dtype=dtype)
#     752
#     753         # At this point array is a NumPy ndarray. We convert it to an array
#     754         # container that is consistent with the input's namespace.
#
# /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, dtype)
#    2082     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083         values = self._values
# -> 2084         arr = np.asarray(values, dtype=dtype)
#    2085         if (
#    2086             astype_is_view(values.dtype, arr.dtype)
#    2087             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'T3'

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Determine the number of input features
input_features = X_train_scaled.shape[1]

# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=input_features))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 80)             │         4,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │         2,430 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,541 (25.55 KB)
#  Trainable params: 6,541 (25.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = nn.fit(
    X_train_scaled, 
    y_train, 
    epochs=100, 
    batch_size=32, 
    verbose=1, 
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 1s 359us/step - accuracy: 0.6790 - loss: 0.6054 - val_accuracy: 0.7383 - val_loss: 0.5427
# Epoch 2/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step - accuracy: 0.7295 - loss: 0.5518 - val_accuracy: 0.7402 - val_loss: 0.5433
# Epoch 3/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.7283 - loss: 0.5514 - val_accuracy: 0.7383 - val_loss: 0.5451
# Epoch 4/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.7303 - loss: 0.5500 - val_accuracy: 0.7371 - val_loss: 0.5442
# Epoch 5/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7338 - loss: 0.5433 - val_accuracy: 0.7378 - val_loss: 0.5422
# Epoch 6/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.7341 - loss: 0.5450 - val_accuracy: 0.7387 - val_loss: 0.5435
# Epoch 7/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7297 - loss: 0.5504 - val_accuracy: 0.7376 - val_loss: 0.5422
# Epoch 8/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.7316 - loss: 0.5427 - val_accuracy: 0.7389 - val_loss: 0.5430
# Epoch 9/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step - accuracy: 0.7316 - loss: 0.5451 - val_accuracy: 0.7358 - val_loss: 0.5407
# Epoch 10/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.7328 - loss: 0.5434 - val_accuracy: 0.7382 - val_loss: 0.5415
# Epoch 11/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.7304 - loss: 0.5428 - val_accuracy: 0.7392 - val_loss: 0.5406
# Epoch 12/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - accuracy: 0.7307 - loss: 0.5445 - val_accuracy: 0.7398 - val_loss: 0.5424
# Epoch 13/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step - accuracy: 0.7311 - loss: 0.5437 - val_accuracy: 0.7385 - val_loss: 0.5429
# Epoch 14/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.7323 - loss: 0.5435 - val_accuracy: 0.7378 - val_loss: 0.5406
# Epoch 15/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step - accuracy: 0.7335 - loss: 0.5437 - val_accuracy: 0.7394 - val_loss: 0.5403
# Epoch 16/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 289us/step - accuracy: 0.7376 - loss: 0.5377 - val_accuracy: 0.7394 - val_loss: 0.5423
# Epoch 17/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.7328 - loss: 0.5432 - val_accuracy: 0.7356 - val_loss: 0.5424
# Epoch 18/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step - accuracy: 0.7328 - loss: 0.5409 - val_accuracy: 0.7374 - val_loss: 0.5399
# Epoch 19/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.7345 - loss: 0.5421 - val_accuracy: 0.7402 - val_loss: 0.5429
# Epoch 20/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 311us/step - accuracy: 0.7348 - loss: 0.5392 - val_accuracy: 0.7398 - val_loss: 0.5407
# Epoch 21/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.7348 - loss: 0.5410 - val_accuracy: 0.7389 - val_loss: 0.5421
# Epoch 22/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 288us/step - accuracy: 0.7352 - loss: 0.5388 - val_accuracy: 0.7392 - val_loss: 0.5412
# Epoch 23/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.7344 - loss: 0.5400 - val_accuracy: 0.7409 - val_loss: 0.5423
# Epoch 24/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.7305 - loss: 0.5443 - val_accuracy: 0.7378 - val_loss: 0.5440
# Epoch 25/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.7321 - loss: 0.5429 - val_accuracy: 0.7389 - val_loss: 0.5426
# Epoch 26/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.7354 - loss: 0.5395 - val_accuracy: 0.7385 - val_loss: 0.5423
# Epoch 27/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step - accuracy: 0.7301 - loss: 0.5445 - val_accuracy: 0.7392 - val_loss: 0.5421
# Epoch 28/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step - accuracy: 0.7357 - loss: 0.5357 - val_accuracy: 0.7394 - val_loss: 0.5432
# Epoch 29/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 288us/step - accuracy: 0.7416 - loss: 0.5323 - val_accuracy: 0.7374 - val_loss: 0.5425
# Epoch 30/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.7384 - loss: 0.5413 - val_accuracy: 0.7360 - val_loss: 0.5434
# Epoch 31/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.7385 - loss: 0.5383 - val_accuracy: 0.7383 - val_loss: 0.5419
# Epoch 32/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.7381 - loss: 0.5326 - val_accuracy: 0.7387 - val_loss: 0.5419
# Epoch 33/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.7360 - loss: 0.5384 - val_accuracy: 0.7382 - val_loss: 0.5434
# Epoch 34/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 284us/step - accuracy: 0.7351 - loss: 0.5405 - val_accuracy: 0.7385 - val_loss: 0.5430
# Epoch 35/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 287us/step - accuracy: 0
100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7402 - loss: 0.5369 - val_accuracy: 0.7400 - val_loss: 0.5494
# Epoch 70/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 305us/step - accuracy: 0.7444 - loss: 0.5281 - val_accuracy: 0.7400 - val_loss: 0.5473
# Epoch 71/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.7383 - loss: 0.5344 - val_accuracy: 0.7391 - val_loss: 0.5470
# Epoch 72/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7367 - loss: 0.5345 - val_accuracy: 0.7378 - val_loss: 0.5472
# Epoch 73/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7422 - loss: 0.5301 - val_accuracy: 0.7398 - val_loss: 0.5459
# Epoch 74/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step - accuracy: 0.7405 - loss: 0.5322 - val_accuracy: 0.7382 - val_loss: 0.5506
# Epoch 75/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.7378 - loss: 0.5317 - val_accuracy: 0.7398 - val_loss: 0.5469
# Epoch 76/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 300us/step - accuracy: 0.7385 - loss: 0.5370 - val_accuracy: 0.7398 - val_loss: 0.5477
# Epoch 77/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7344 - loss: 0.5386 - val_accuracy: 0.7385 - val_loss: 0.5467
# Epoch 78/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 329us/step - accuracy: 0.7383 - loss: 0.5317 - val_accuracy: 0.7398 - val_loss: 0.5482
# Epoch 79/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 283us/step - accuracy: 0.7388 - loss: 0.5337 - val_accuracy: 0.7389 - val_loss: 0.5471
# Epoch 80/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - accuracy: 0.7374 - loss: 0.5322 - val_accuracy: 0.7382 - val_loss: 0.5474
# Epoch 81/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7408 - loss: 0.5321 - val_accuracy: 0.7372 - val_loss: 0.5494
# Epoch 82/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step - accuracy: 0.7373 - loss: 0.5304 - val_accuracy: 0.7383 - val_loss: 0.5458
# Epoch 83/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7403 - loss: 0.5300 - val_accuracy: 0.7400 - val_loss: 0.5464
# Epoch 84/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - accuracy: 0.7403 - loss: 0.5315 - val_accuracy: 0.7398 - val_loss: 0.5473
# Epoch 85/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7337 - loss: 0.5357 - val_accuracy: 0.7411 - val_loss: 0.5485
# Epoch 86/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7392 - loss: 0.5332 - val_accuracy: 0.7400 - val_loss: 0.5485
# Epoch 87/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.7408 - loss: 0.5322 - val_accuracy: 0.7400 - val_loss: 0.5479
# Epoch 88/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7354 - loss: 0.5364 - val_accuracy: 0.7405 - val_loss: 0.5470
# Epoch 89/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - accuracy: 0.7408 - loss: 0.5311 - val_accuracy: 0.7422 - val_loss: 0.5475
# Epoch 90/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 296us/step - accuracy: 0.7458 - loss: 0.5258 - val_accuracy: 0.7351 - val_loss: 0.5503
# Epoch 91/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7389 - loss: 0.5302 - val_accuracy: 0.7398 - val_loss: 0.5502
# Epoch 92/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step - accuracy: 0.7356 - loss: 0.5372 - val_accuracy: 0.7411 - val_loss: 0.5495
# Epoch 93/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step - accuracy: 0.7394 - loss: 0.5315 - val_accuracy: 0.7409 - val_loss: 0.5499
# Epoch 94/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7360 - loss: 0.5335 - val_accuracy: 0.7392 - val_loss: 0.5500
# Epoch 95/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 291us/step - accuracy: 0.7436 - loss: 0.5307 - val_accuracy: 0.7392 - val_loss: 0.5508
# Epoch 96/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7428 - loss: 0.5273 - val_accuracy: 0.7413 - val_loss: 0.5480
# Epoch 97/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 278us/step - accuracy: 0.7399 - loss: 0.5348 - val_accuracy: 0.7382 - val_loss: 0.5489
# Epoch 98/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 279us/step - accuracy: 0.7392 - loss: 0.5317 - val_accuracy: 0.7383 - val_loss: 0.5516
# Epoch 99/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 298us/step - accuracy: 0.7391 - loss: 0.5306 - val_accuracy: 0.7400 - val_loss: 0.5482
# Epoch 100/100
# 686/686 ━━━━━━━━━━━━━━━━━━━━ 0s 280us/step - accuracy: 0.7385 - loss: 0.5377 - val_accuracy: 0.7398 - val_loss: 0.5480

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - 201us/step - accuracy: 0.7273 - loss: 0.5627
# Loss: 0.5626733303070068, Accuracy: 0.7272594571113586

# %%
# Export our model to HDF5 file
nn.save('trained_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
